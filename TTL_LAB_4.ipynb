# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('TTLdataanalytics2.csv')

# %%
df.head()
# Out:
#    FINAL_DIRECT_APPEND_DH38_WIR_HW    OSR  WRT_RES  \
# 0                         0.001706  21.23     1.08
# 1                        -0.000438  21.21     1.08
# 2                        -0.000866  21.40     1.08
# 3                        -0.001413  21.64     1.08
# 4                        -0.000707  21.51     1.07
#
#    dt_FINAL_TARGET_SLIDER_HW_TARGET_BEF_LOCK    dt_HRW    dt_OSR  dt_WELG_RES  \
# 0                                   0.001686 -0.501472  0.798269     0.251041
# 1                                  -0.001028 -0.731472  0.778269     0.211041
# 2                                  -0.001991 -0.831472  0.968269     0.191041
# 3                                  -0.002944 -0.821472  1.208269     0.151041
# 4                                  -0.002646 -0.661472  1.078269     0.161041
#
#    dt_WRT_RES BLOCK  ROW  COLUMN FF_ID  WAFER  dt_act_sseb SS1_EXP_TOOL  \
# 0   -0.047953     A    1       7  R3C1  0AJ62     3.730049        EXP21
# 1   -0.047953     A    1       8  R3C1  0AJ62    -1.585379        EXP21
# 2   -0.047953     A    1       9  R3C1  0AJ62    -1.828795        EXP21
# 3   -0.047953     A    1      10  R3C1  0AJ62    -5.321527        EXP21
# 4   -0.057953     A    1      11  R3C1  0AJ62    -3.948698        EXP21
#
#   DT7D_TMR_EXP_TOOL
# 0             EXP21
# 1             EXP21
# 2             EXP21
# 3             EXP21
# 4             EXP21

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11984\3627053830.py in <module>
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %%
boxplot=df.boxplot(figsize = (15,15), rot=90, fontsize='8', grid= False)

# %%
df= sns.load_dataset('tips')
sns.pairplot(df, hue='size')
plt.show()

# %%
df.hist(bins=10)
plt.xlim([0,100])
plt.ylim([50,500])
plt.title("Data")
plt.xlabel("fruits")
plt.ylabel("Frequency")
plt.show()

# %%
pd.read_csv('TTLdataanalytics2.csv')
X = df.iloc[:, :-1].values
y = df.iloc[:, -3].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
print(X)
# Out:
# [[16.99 1.01 'Female' 'No' 'Sun' 'Dinner']
#  [10.34 1.66 'Male' 'No' 'Sun' 'Dinner']
#  [21.01 3.5 'Male' 'No' 'Sun' 'Dinner']
#  ...
#  [22.67 2.0 'Male' 'Yes' 'Sat' 'Dinner']
#  [17.82 1.75 'Male' 'No' 'Sat' 'Dinner']
#  [18.78 3.0 'Female' 'No' 'Thur' 'Dinner']]

# %%
print(y)
# Out:
# ['Sun', 'Sun', 'Sun', 'Sun', 'Sun', ..., 'Sat', 'Sat', 'Sat', 'Sat', 'Thur']
# Length: 244
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']
